# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('titanic/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.where(df['Cabin'] != 'NaN').head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.loc[[0,10,25],['Name','Age','Survived']]
# Out:
#                                                  Name   Age  Survived
# 0                             Braund, Mr. Owen Harris  22.0         0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0         1
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0         1

# %%
df.loc[:,['Fare','Survived']]
# Out:
#         Fare  Survived
# 0     7.2500         0
# 1    71.2833         1
# 2     7.9250         1
# 3    53.1000         1
# 4     8.0500         0
# ..       ...       ...
# 886  13.0000         0
# 887  30.0000         1
# 888  23.4500         0
# 889  30.0000         1
# 890   7.7500         0
#
# [891 rows x 2 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[(df['Survived'] == 1) & (df['Sex'] == 'male') & ~(df['Cabin'].isnull())]
# Out:
#      PassengerId  Survived  Pclass  \
# 21            22         1       2
# 23            24         1       1
# 55            56         1       1
# 97            98         1       1
# 183          184         1       2
# 193          194         1       2
# 209          210         1       1
# 224          225         1       1
# 248          249         1       1
# 298          299         1       1
# 305          306         1       1
# 340          341         1       2
# 370          371         1       1
# 390          391         1       1
# 429          430         1       3
# 430          431         1       1
# 445          446         1       1
# 449          450         1       1
# 453          454         1       1
# 460          461         1       1
# 484          485         1       1
# 512          513         1       1
# 550          551         1       1
# 572          573         1       1
# 587          588         1       1
# ...

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
gender_counts = df.groupby('Sex').size()
print("Total number of passengers by gender")
print(gender_counts)
# Out:
# Total number of passengers by gender
# Sex
# female    314
# male      577
# dtype: int64

# %%
mean_age = df.groupby('Sex')['Age'].mean()
print("mean age by gender:")
print(mean_age)
# Out:
# mean age by gender:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
gender_class_counts = df.groupby(['Pclass','Sex']).size()
print('Number of males and females per class')
print(gender_class_counts)
# Out:
# Number of males and females per class
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64
